# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajkumar97040/FMML_Project_Labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 15:33:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   101MB/s    in 0.7s
#
# 2024-04-05 15:33:18 (101 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3650 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26024  1608.03609v1  Recent years have seen tremendous progress in ...    cs
# 7482   1801.04053v1  We present a noise-injected version of the Exp...  stat
# 18519   1103.5034v2  In the present paper, we try to propose a self...    cs
# 4805   1510.03336v4  Much of the world's data is streaming, time-se...    cs
# 1296    1405.6137v1  The improvements in spectral and spatial resol...    cs
# ...             ...                                                ...   ...
# 5744    1206.3252v1  When related learning tasks are naturally arra...    cs
# 25440  1509.01514v1  The most efficient signal edge-preserving smoo...    cs
# 21821   1212.1263v1  In this paper we prove the probabilistic conti...  stat
# 39860  1706.06480v2  The inner structure of a material is called mi...    cs
# 15544  1509.01692v4  Recent work on word embeddings has shown that ...    cs
#
#                                                    title  year  \
# 26024  Clockwork Convnets for Video Semantic Segmenta...  2016
# 7482   Noisy Expectation-Maximization: Applications a...  2018
# 18519         On Understanding and Machine Understanding  2011
# 4805   Evaluating Real-time Anomaly Detection Algorit...  2015
# 1296   An enhanced neural network based approach towa...  2014
# ...                                                  ...   ...
# 5744   Convex Point Estimation using Undirected Bayes...  2012
# 25440  Conjugate Gradient Acceleration of Non-Linear ...  2015
# 21821  On the probabilistic continuous complexity con...  2012
# 39860  Advanced Steel Microstructural Classification ...  2017
# 15544  Take and Took, Gaggle and Goose, Book and Read...  2015
#
#                                                 keywords
# 26024  [tremendous, segmentation, application, algori...
# 7482   [expectation, maximization, algorithm, expecta...
# 18519  [understanding, extending, languages, sufficie...
# 4805   [streaming, anomalies, significant, informatio...
# 1296   [improvements, resolution, satellite, facilita...
# ...                                                  ...
# 5744   [naturally, hierarchy, appealing, instances, h...
# 25440  [efficient, preserving, smoothing, denoising, ...
# 21821  [probabilistic, continuous, complexity, conjec...
# 39860  [structure, microstructure, determines, proper...
# 15544  [embeddings, subtraction, embeddings, surprisi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26024    [tremendous, segmentation, application, algori...
# 7482     [expectation, maximization, algorithm, expecta...
# 18519    [understanding, extending, languages, sufficie...
# 4805     [streaming, anomalies, significant, informatio...
# 1296     [improvements, resolution, satellite, facilita...
#                                ...
# 22672    [algorithms, formulated, algorithms, functions...
# 30506    [identifying, continuously, streaming, applica...
# 7657     [scientific, engineering, processes, dimension...
# 2696     [convergence, proposals, parametric, propertie...
# 30249    [convolutional, effective, recognition, extens...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8722 words.
# Out of those 4561 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="26f41b1f-15da-4463-bed2-940ddfdf81c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26f41b1f-15da-4463-bed2-940ddfdf81c1")) {                    Plotly.newPlot(                        "26f41b1f-15da-4463-bed2-940ddfdf81c1",                        [{"x":["cityscapes","efficiency","framework","stability","unlabeled","computation","schedules","recognition","continuity","segmentation","application","according","execution","tremendous","processing","considerable","incorporating","evaluated","observations","algorithms","scheduling","different","architecture","injection","pronounced","likelihood","convergence","injecting","multiplying","generalized","condition","decreases","applications","identically","including","demonstrate","generalizations","independent","maximization","arbitrary","algorithm","distributed","expectation","presented","positivity","multiplicative","influences","understanding","familiarity","extending","surrounding","environment","addressing","investigation","languages","influence","constructing","searching","discussion","sufficient","discussed","predictions","rewarding","adequately","difficult","components","community","detectors","formalized","anomalies","detection","benchmark","controlled","streaming","repeatable","benchmarks","commercially","simultaneously","automatically","statistics","situations","information","significant","requiring","detecting","evaluating","evaluates","characteristics","automatic","effectiveness","intelligent","increases","interpretation","extraction","advantage","facilitated","resolution","flexibility","verification","identifying","satellite","interpolation","identification","simulates","improvements","photographs","successful","identifies","performance","extracting","simplicity","evaluation","theoretical","illustrate","empirically","alternate","continuous","probabilities","underlying","transition","parameter","difference","corrected","eligibility","formalize","relationship","conditions","approximate","corrections","abstraction","decomposition","important","developed","converges","abstractions","primitive","terminating","reinforcement","experimentally","hierarchical","researchers","optimization","reduction","explorations","modularity","successes","vectorization","advantages","correctness","translation","harnessing","synthesis","solutions","expressions","guarantees","reasoning","challenges","dimensionality","heuristics","feasibility","satisfiability","representing","shortcomings","interpret","intuitive","understand","scientific","visualizing","visualization","distributions","impression","permutation","extracted","presentations","abstracts","methodology","distribution","outperforms","semantics","performances","representations","conjunction","descriptions","relational","combining","leverages","embeddings","available","improving","knowledge","illustrates","resources","regarding","decreasing","understood","initialization","leveraging","distributional","propositional","conditional"],"y":[7,171,549,37,42,143,4,370,7,206,253,122,27,12,262,40,38,134,73,615,19,744,239,6,2,74,125,2,1,72,49,17,436,5,245,548,8,125,43,85,801,101,39,170,0,9,15,152,1,41,16,98,32,28,100,64,36,38,39,77,48,84,2,7,148,104,79,37,13,12,347,214,42,12,2,99,3,112,181,62,44,640,232,50,84,56,20,84,194,219,58,54,47,142,84,5,117,35,41,71,14,18,111,6,117,10,79,25,864,55,20,263,162,84,79,5,106,61,133,29,116,56,5,3,8,73,153,106,8,31,61,335,204,20,12,13,2,129,52,110,66,308,103,1,8,12,3,73,23,116,5,44,162,48,68,101,136,57,48,33,22,81,13,19,28,54,31,7,25,127,2,8,100,1,2,69,203,271,83,48,238,23,29,28,101,36,96,304,107,303,17,70,34,7,22,27,44,15,35,117],"type":"bar"},{"x":["cityscapes","efficiency","framework","stability","unlabeled ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4561,), (4561, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8008333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Effect</span> <span style=''>of</span> <span style=''>Color</span> <span style=''>Space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>Detectability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Discriminability</span> <span style=''>of</span> <span style=''>Colored</span> <span style=''>Objects</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style=''>color</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>detectability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>discriminability</span> <span style=''>of</span> <span style=''>colored</span> <span style=''>objects</span> <span style=''>under</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>20</span> <span style=''>color</span> <span style=''>spaces</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.39583333333333326);'>evaluated</span> <span style=''>on</span> <span style=''>a</span> <span style=''>large</span> <span style=''>dataset</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3990147783251232);'>simulated</span> <span style=''>and</span> <span style=''>real</span> <span style=''>images</span> <span style=''>We</span> <span style=''>measure</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4);'>suitability</span> <span style=''>of</span> <span style=''>color</span> <span style=''>spaces</span> <span style=''>from</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3203194321206744);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspectives</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666666);'>detectability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>discriminability</span> <span style=''>of</span> <span style=''>various</span> <span style=''>color</span> <span style=''>groups</span> <span style=''>Through</span> <span style='background-color:rgba(0, 255, 0, 0.4011299435028248);'>experimental</span> <span style='background-color:rgba(0, 255, 0, 0.41778975741239893);'>evaluation</span> <span style=''>we</span> <span style=''>found</span> <span style=''>that</span> <span style=''>there</span> <span style=''>is</span> <span style=''>no</span> <span style=''>single</span> <span style=''>optimal</span> <span style=''>color</span> <span style=''>space</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>all</span> <span style=''>color</span> <span style=''>groups</span> <span style=''>The</span> <span style=''>color</span> <span style=''>spaces</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3203194321206744);'>different</span> <span style=''>levels</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitivity</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3203194321206744);'>different</span> <span style=''>color</span> <span style=''>groups</span> <span style=''>and</span> <span style=''>they</span> <span style=''>are</span> <span style=''>useful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>on ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multinomial</span> <span style=''>Models</span> <span style=''>Made</span> <span style=''>Easy</span> <span style=''>Stick</span> <span style=''>Breaking</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Pólya</span> <span style=''>Gamma</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Augmentation</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>modeling</span> <span style=''>problems</span> <span style=''>involve</span> <span style=''>discrete</span> <span style=''>data</span> <span style=''>that</span> <span style=''>are</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>as</span> <span style=''>draws</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multinomial</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>categorical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>For</span> <span style=''>example</span> <span style=''>nucleotides</span> <span style=''>in</span> <span style=''>a</span> <span style=''>DNA</span> <span style=''>sequence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>childrens</span> <span style=''>names</span> <span style=''>in</span> <span style=''>a</span> <span style=''>given</span> <span style=''>state</span> <span style=''>and</span> <span style=''>year</span> <span style=''>and</span> <span style=''>text</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documents</span> <span style=''>are</span> <span style=''>all</span> <span style=''>commonly</span> <span style=''>modeled</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multinomial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>In</span> <span style=''>all</span> <span style=''>of</span> <span style=''>these</span> <span style=''>cases</span> <span style=''>we</span> <span style=''>expect</span> <span style=''>some</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependency</span> <span style=''>between</span> <span style=''>the</span> <span style=''>draws</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nucleotide</span> <span style=''>at</span> <span style=''>one</span> <span style=''>position</span> <span style=''>in</span> <span style=''>the</span> <span style=''>DNA</span> <span style=''>strand</span> <span style=''>may</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preceding</span> <span style=''>nucleotides</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>childrens</span> <span style=''>names</span> <span style=''>are</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>from</span> <span style=''>year</span> <span style=''>to</span> <span style=''>year</span> <span style=''>and</span> <span style=''>topics</span> <span style=''>in</span> <span style=''>text</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style=''>and</span> <span style=''>dynamic</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>captured</span> <span style=''>by</span> <span style=''>the</span> <span style=''>typical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Simultaneous</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>of</span> <span style=''>motion</span> <span style=''>velocity</span> <span style=''>fields</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successive</span> <span style=''>video</span> <span style=''>frames</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>by</span> <span style=''>spatio</span> <span style=''>temporal</span> <span style=''>MRFs</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>numerically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>a</span> <span style=''>mean</span> <span style=''>field</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636364);'>assistance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>method</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>motion</span> <span style=''>velocity</span> <span style=''>fields</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.4);'>consecutive</span> <span style=''>digital</span> <span style=''>images</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>by</span> <span style=''>spatio</span> <span style=''>temporal</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <span style='background-color:rgba(0, 255, 0, 0.3076923076923076);'>Preliminary</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>we</span> <span style=''>find</span> <span style=''>that</span> <span style=''>mean</span> <span style=''>field</span> <span style='background-color:rgba(255, 0, 0, 0.33497536945812806);'>variables</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>diverge</span> <span style=''>due</span> <span style=''>to</span> <span style=''>improper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalization</span> <span style=''>factor</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>terms</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>appearing</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>posterior</span> <span style=''>To</span> <span style=''>avoid</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulty</span> <span style=''>we</span> <span style=''>rescale</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>term</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.31868131868131866);'>introducing</span> <span style=''>a</span> <span style=''>scaling</span> <span style=''>factor</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Dawid</span> <span style=''>Skene</span> <br/><br/><span style=''>Many</span> <span style=''>real</span> <span style=''>world</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>now</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>solved</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>A</span> <span style=''>major</span> <span style=''>roadblock</span> <span style=''>is</span> <span style=''>often</span> <span style=''>the</span> <span style=''>lack</span> <span style=''>of</span> <span style=''>an</span> <span style=''>adequate</span> <span style=''>quantity</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>for</span> <span style=''>training</span> <span style=''>A</span> <span style=''>possible</span> <span style=''>solution</span> <span style=''>is</span> <span style=''>to</span> <span style=''>assign</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>labeling</span> <span style=''>data</span> <span style=''>to</span> <span style=''>a</span> <span style=''>crowd</span> <span style=''>and</span> <span style=''>then</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>true</span> <span style=''>label</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>methods</span> <span style=''>A</span> <span style=''>well</span> <span style=''>known</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>is</span> <span style=''>the</span> <span style=''>Dawid</span> <span style=''>Skene</span> <span style=''>(DS)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Maximization</span> <span style=''>(EM)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>EM</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style=''>a</span> <span style=''>hard</span> <span style=''>version</span> <span style=''>of</span> <span style=''>DS</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>much</span> <span style=''>faster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>similar</span> <span style=''>accuracy</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>can</span> <span style=''>be</span> <span style=''>extended</span> <span style=''>to</span> <span style=''>settings</span> <span style=''>when</span> <span style=''>there</span> <span style=''>are</span> <span style=''>multipl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09332860184528034)
# 	automatic (0.0688431511710433)
# 	architecture (0.08481192334989354)
# 	experimental (0.1320085166784954)
# 	representation (0.1376863023420866)
# 	segmentation (0.07310149041873669)
# 	different (0.2640170333569908)
# 	detection (0.12313697657913414)
# 	recognition (0.1312987934705465)
# 	convolutional (0.14868701206529453)
#
# Some Statistics words are:
# 	variables (0.1367305751765893)
# 	stochastic (0.13471241170534815)
# 	estimation (0.16750756811301715)
# 	theoretical (0.15287588294651866)
# 	statistical (0.15893037336024218)
# 	algorithm (0.39455095862764883)
# 	distribution (0.1841574167507568)
# 	inference (0.19677093844601412)
# 	dimensional (0.18920282542885974)
# 	regression (0.1846619576185671)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ceb2ffa4-8662-4b7d-9a85-534db0cf6404" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ceb2ffa4-8662-4b7d-9a85-534db0cf6404")) {                    Plotly.newPlot(                        "ceb2ffa4-8662-4b7d-9a85-534db0cf6404",                        [{"x":["cityscapes","efficiency","framework","stability","unlabeled","computation","schedules","recognition","continuity","segmentation","application","according","execution","tremendous","processing","considerable","incorporating","evaluated","observations","algorithms","scheduling","different","architecture","injection","pronounced","likelihood","convergence","injecting","multiplying","generalized","condition","decreases","applications","identically","including","demonstrate","generalizations","independent","maximization","arbitrary","algorithm","distributed","expectation","presented","positivity","multiplicative","influences","understanding","familiarity","extending","surrounding","environment","addressing","investigation","languages","influence","constructing","searching","discussion","sufficient","discussed","predictions","rewarding","adequately","difficult","components","community","detectors","formalized","anomalies","detection","benchmark","controlled","streaming","repeatable","benchmarks","commercially","simultaneously","automatically","statistics","situations","information","significant","requiring","detecting","evaluating","evaluates","characteristics","automatic","effectiveness","intelligent","increases","interpretation","extraction","advantage","facilitated","resolution","flexibility","verification","identifying","satellite","interpolation","identification","simulates","improvements","photographs","successful","identifies","performance","extracting","simplicity","evaluation","theoretical","illustrate","empirically","alternate","continuous","probabilities","underlying","transition","parameter","difference","corrected","eligibility","formalize","relationship","conditions","approximate","corrections","abstraction","decomposition","important","developed","converges","abstractions","primitive","terminating","reinforcement","experimentally","hierarchical","researchers","optimization","reduction","explorations","modularity","successes","vectorization","advantages","correctness","translation","harnessing","synthesis","solutions","expressions","guarantees","reasoning","challenges","dimensionality","heuristics","feasibility","satisfiability","representing","shortcomings","interpret","intuitive","understand","scientific","visualizing","visualization","distributions","impression","permutation","extracted","presentations","abstracts","methodology","distribution","outperforms","semantics","performances","representations","conjunction","descriptions","relational","combining","leverages","embeddings","available","improving","knowledge","illustrates","resources","regarding","decreasing","understood","initialization","leveraging","distributional","propositional","conditional","explained","translating","constructs","designers","intuition","straightforward","transformations","aggregates","mathematically","variables","equivalent","definition","deduction","references","investigated","alternative","optimisation","concerned","clustering","organisation","computing","accelerate","biological","constraints","counterparts","accelerating","extension","considered","ecosystem","architectures","evolutionary","established","continuously","operating","organising","migration","complexity","populations","ecosystems","decentralised","augmentations","optimising","diversity","ecological","properties","technique","exploiting","resulting","functions","separable","particularly","simultaneous","supervised ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	positivity
# 	polyhedral
# 	vectorial
# 	abandonment
# 	backpropagating
# 	particulars
# 	individualized
# 	penalization
# 	byproduct
# 	premature
# 	nonparametrically
# 	confounders
# 	astrophysics
# 	informally
# 	recombines
# 	contracting
# 	allocating
# 	precludes
# 	continuation
# 	hoeffding
# Some words which never appear in Statistics papers:
# 	cityscapes
# 	repeatable
# 	commercially
# 	eligibility
# 	terminating
# 	vectorization
# 	satisfiability
# 	propositional
# 	ecosystem
# 	organising
# 	ecosystems
# 	ecological
# 	treewidths
# 	pedestrian
# 	occlusions
# 	cartesian
# 	appearances
# 	overheads
# 	configure
# 	infrastructures

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0542744571027155e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7558333333333334
